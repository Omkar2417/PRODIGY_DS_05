# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
df = sns.load_dataset("penguins")

# %%
data=pd.read_csv("C:/Users/mrudu/Downloads/Kaagle_Upload.csv.zip")
# Out:
# C:\Users\mrudu\AppData\Local\Temp\ipykernel_1716\2286104057.py:1: DtypeWarning: Columns (0,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("C:/Users/mrudu/Downloads/Kaagle_Upload.csv.zip")

# %%
data.head()
# Out:
#   accident_index  vehicle_reference  vehicle_type  towing_and_articulation  \
# 0  201506E098757                  2             9                        0
# 1  201506E098766                  1             9                        0
# 2  201506E098766                  2             9                        0
# 3  201506E098777                  1            20                        0
# 4  201506E098780                  1             9                        0
#
#    vehicle_manoeuvre  vehicle_location-restricted_lane  junction_location  \
# 0                 18                                 0                  8
# 1                  9                                 0                  8
# 2                 18                                 0                  8
# 3                  4                                 0                  0
# 4                 15                                 0                  1
#
#    skidding_and_overturning  hit_object_in_carriageway  \
# ...

# %%
data.tail()
# Out:
#        accident_index  vehicle_reference  vehicle_type  \
# 285326  2015984141415                  9             9
# 285327  2015984141415                 10             9
# 285328  2015984141415                 11             9
# 285329  2015984141415                 12             9
# 285330  2015984141415                 13             9
#
#         towing_and_articulation  vehicle_manoeuvre  \
# 285326                        0                 18
# 285327                        0                 18
# 285328                        0                 18
# 285329                        0                 18
# 285330                        0                 18
#
#         vehicle_location-restricted_lane  junction_location  \
# 285326                                 0                  0
# 285327                                 0                  0
# 285328                                 0                  0
# 285329                                 0                  0
# ...

# %%
print("No. of Rows :",data.shape[0])
print("No. of Columns :",data.shape[1])
# Out:
# No. of Rows : 285331
# No. of Columns : 70

# %%
data.columns
# Out:
# Index(['accident_index', 'vehicle_reference', 'vehicle_type',
#        'towing_and_articulation', 'vehicle_manoeuvre',
#        'vehicle_location-restricted_lane', 'junction_location',
#        'skidding_and_overturning', 'hit_object_in_carriageway',
#        'vehicle_leaving_carriageway', 'hit_object_off_carriageway',
#        '1st_point_of_impact', 'was_vehicle_left_hand_drive?',
#        'journey_purpose_of_driver', 'sex_of_driver', 'age_of_driver',
#        'age_band_of_driver', 'engine_capacity_(cc)', 'propulsion_code',
#        'age_of_vehicle', 'driver_imd_decile', 'driver_home_area_type',
#        'vehicle_imd_decile', 'NUmber_of_Casualities_unique_to_accident_index',
#        'No_of_Vehicles_involved_unique_to_accident_index',
#        'location_easting_osgr', 'location_northing_osgr', 'longitude',
#        'latitude', 'police_force', 'accident_severity', 'number_of_vehicles',
#        'number_of_casualties', 'date', 'day_of_week', 'time',
# ...

# %%
data.dtypes
# Out:
# accident_index                         object
# vehicle_reference                       int64
# vehicle_type                            int64
# towing_and_articulation                 int64
# vehicle_manoeuvre                       int64
#                                        ...
# bus_or_coach_passenger                float64
# pedestrian_road_maintenance_worker    float64
# casualty_type                         float64
# casualty_home_area_type               float64
# casualty_imd_decile                   float64
# Length: 70, dtype: object

# %%
data.describe()
# Out:
#        vehicle_reference   vehicle_type  towing_and_articulation  \
# count      285331.000000  285331.000000            285331.000000
# mean            1.557030       9.570765                 0.026741
# std             0.760106       8.515910                 0.289672
# min             1.000000      -1.000000                -1.000000
# 25%             1.000000       9.000000                 0.000000
# 50%             1.000000       9.000000                 0.000000
# 75%             2.000000       9.000000                 0.000000
# max            37.000000      98.000000                 5.000000
#
#        vehicle_manoeuvre  vehicle_location-restricted_lane  junction_location  \
# count      285331.000000                     285331.000000      285331.000000
# mean           12.625323                          0.124038           2.700075
# std             6.191873                          0.965362           3.270800
# ...

# %%
data.isna().sum()
# Out:
# accident_index                            0
# vehicle_reference                         0
# vehicle_type                              0
# towing_and_articulation                   0
# vehicle_manoeuvre                         0
#                                       ...
# bus_or_coach_passenger                99259
# pedestrian_road_maintenance_worker    99259
# casualty_type                         99259
# casualty_home_area_type               99259
# casualty_imd_decile                   99259
# Length: 70, dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# accident_index                        0
# vehicle_reference                     0
# vehicle_type                          0
# towing_and_articulation               0
# vehicle_manoeuvre                     0
#                                      ..
# bus_or_coach_passenger                0
# pedestrian_road_maintenance_worker    0
# casualty_type                         0
# casualty_home_area_type               0
# casualty_imd_decile                   0
# Length: 70, dtype: int64

# %%
data_dup=data.duplicated().any()
print(data_dup)
# Out:
# False

# %%
sns.countplot(x=data['vehicle_reference'])
plt.title("References of Vehicles")
plt.show()

# %%
data=data[data['vehicle_type']!=-1]
sns.countplot(x=data['vehicle_type'])
plt.title("Types of Vehicles")
plt.show()

# %%
sns.histplot(data['vehicle_manoeuvre'],bins=20, stat="count",color='red',kde=False)
plt.show()

# %%
data=data[data['junction_location']!=-1]
sns.countplot(x=data['junction_location'])
plt.title("Locations of Junction")
plt.show()

# %%
data=data[data['1st_point_of_impact']!=-1]
sns.countplot(x=data['1st_point_of_impact'])
plt.show()

# %%
data=data[data['sex_of_driver']!=-1]
sns.countplot(x=data['sex_of_driver'])
plt.show()

# %%
sns.histplot(data['age_of_driver'],bins=20, stat="count",color='blue',kde=False)
plt.title("Driver's Age Distribution")
plt.show()

# %%
data=data[data['age_band_of_driver']!=-1]
age_bands = data['age_band_of_driver'].value_counts()
age_bands
# Out:
# 6     38736
# 7     31512
# 8     27770
# 5     22994
# 4     16345
# 9     14692
# 10     7802
# 11     5040
# 3      1477
# 2       401
# 1        56
# Name: age_band_of_driver, dtype: int64

# %%
plt.figure(figsize=(12,7))
plt.pie(x=age_bands.values, labels=age_bands.index, autopct='%.1f%%')
plt.title('The Difference in age of bands')
plt.show()

# %%
sns.histplot(data['engine_capacity_(cc)'],bins=20, stat="count",color='green',kde=False)
plt.title("Distribution of engine capacity")
plt.show()

# %%
data=data[data['propulsion_code']!=-1]
sns.countplot(x=data['propulsion_code'])
plt.show()

# %%
sns.countplot(x=data['No_of_Vehicles_involved_unique_to_accident_index'])
plt.show()

# %%
sns.lmplot(data=data, x="1st_road_class", y="road_type")
plt.show()

# %%
sns.histplot(data['speed_limit'],bins=20, stat="count",color='orange',kde=True)
plt.title("Speed Limit Distribution")
plt.show()

# %%
sns.countplot(x=data['urban_or_rural_area'])
plt.title("Areas of Accident")
plt.show()

# %%
data=data[data['did_police_officer_attend_scene_of_accident']!=-1]
sns.countplot(x=data['did_police_officer_attend_scene_of_accident'])
plt.show()

# %%
sns.countplot(x=data['casualty_class'])
plt.title("Casualty Class Distribution")
plt.show()

# %%
data=data[data['sex_of_casualty']!=-1]
sns.countplot(x=data['sex_of_casualty'])
plt.show()

# %%
sns.histplot(data['age_of_casualty'],bins=20, stat="count",color='green',kde=True)
plt.title("Casualty Age Distribution")
plt.show()

# %%
data=data[data['casualty_severity']!=-1]
serverity= data['casualty_severity'].value_counts()
serverity
# Out:
# 3.0    108240
# 2.0     13320
# 1.0      1198
# Name: casualty_severity, dtype: int64

# %%
plt.figure(figsize=(12,7))
plt.pie(x=serverity.values, labels=serverity.index, autopct='%.1f%%')
plt.title("Serverity Frequency Distribution")
plt.show()

# %%
data=data[data['car_passenger']!=-1]
data=data[data['bus_or_coach_passenger']!=-1]
sns.violinplot(x='car_passenger',y='bus_or_coach_passenger',data=data,palette='pastel')
plt.show()
